# %%
# Q1 String
a= "Hello"
print (a)
# Out:
# Hello

# %%
type(a)
# Out:
# str

# %%
#list
l= ["name", 5, True , 4+6j]
print(l)
# Out:
# ['name', 5, True, (4+6j)]

# %%
type(l)
# Out:
# list

# %%
# float
f= 2.4
type(f)
# Out:
# float

# %%
#tuple
a= ("apple", "banana", "abc", 34, True, 40, "male", ["1", True, 5.6])
print (a)
type(a)
# Out:
# ('apple', 'banana', 'abc', 34, True, 40, 'male', ['1', True, 5.6])
# tuple

# %%
#Q2. Given are some following variables containing data:
#What will be the data type of the above given variable.
var1 =  ' '



type (var1)
# Out:
# str

# %%
var2 = '[ DS , ML , Python]'
type (var2)
# Out:
# str

# %%
var3 = [ 'DS' , 'ML' , 'Python' ]
type (var3)
# Out:
# list

# %%
var4 = 1.
type(var4)
# Out:
# float

# %%
#Q3. Explain the use of the following operators using an example:

(i)	/

(ii)	% 

(iii)	//

(iv)	*

# %%
#(i)	/ - division

print (10/2)
# Out:
# 5.0

# %%
#(ii)	% - gives reminder

print(10%5)
print (3%2)
# Out:
# 0
# 1

# %%
#(iii)	// -Floor division-rounds the result down to the nearest whole number
print (4//3)
# Out:
# 1

# %%
#(iv)	* - MUltiplication
print( 10*12)
# Out:
# 120

# %%
#Q4. Create a list of length 10 of your choice containing multiple types of data. Using for loop print the 
#element and its data type

l= ["apple", "banana", "abc", 34, True, 40+6j, 2.50, True , False, 100, range(10)]
for x in l:
    print(x, type(x))
# Out:
# apple <class 'str'>
# banana <class 'str'>
# abc <class 'str'>
# 34 <class 'int'>
# True <class 'bool'>
# (40+6j) <class 'complex'>
# 2.5 <class 'float'>
# True <class 'bool'>
# False <class 'bool'>
# 100 <class 'int'>
# range(0, 10) <class 'range'>

# %%
#Q5. Using a while loop, verify if the number A is purely divisible by number B and if so then how many 
#times it can be divisible.
A = int(input(" Enter the value of A"))
while A%8==0 :
    print( "A is purely divisible by 8"," it is divisible by", A/8, "times")
    break
else:
    print(" A is not purely divisible by 8")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[49], line 3
#       1 #Q5. Using a while loop, verify if the number A is purely divisible by number B and if so then how many
#       2 #times it can be divisible.
# ----> 3 A = int(input(" Enter the value of A"))
#       4 while A%8==0 :
#       5     print( "A is purely divisible by 8"," it is divisible by", A/8, "times")
#
# File /opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py:1175, in Kernel.raw_input(self, prompt)
#    1171 if not self._allow_stdin:
#    1172     raise StdinNotImplementedError(
#    1173         "raw_input was called, but this frontend does not support input requests."
#    1174     )
# -> 1175 return self._input_request(
#    1176     str(prompt),
#    1177     self._parent_ident["shell"],
#    1178     self.get_parent("shell"),
#    1179     password=False,
#    1180 )
#
# ...

# %%
#Q6. Create a list containing 25 int type data. Using for loop and if-else condition print if the element is 
#divisible by 3 or not.

R= list(range (5,31))
for x in R:
    if x%3==0 :
        print(x ,"is divisible by 3")
    else :
        print (x ,"is not divisible by 3")
# Out:
# 5 is not divisible by 3
# 6 is divisible by 3
# 7 is not divisible by 3
# 8 is not divisible by 3
# 9 is divisible by 3
# 10 is not divisible by 3
# 11 is not divisible by 3
# 12 is divisible by 3
# 13 is not divisible by 3
# 14 is not divisible by 3
# 15 is divisible by 3
# 16 is not divisible by 3
# 17 is not divisible by 3
# 18 is divisible by 3
# 19 is not divisible by 3
# 20 is not divisible by 3
# 21 is divisible by 3
# 22 is not divisible by 3
# 23 is not divisible by 3
# 24 is divisible by 3
# 25 is not divisible by 3
# 26 is not divisible by 3
# 27 is divisible by 3
# 28 is not divisible by 3
# 29 is not divisible by 3
# 30 is divisible by 3

# %%
#Q7. What do you understand about mutable and immutable data types? Give examples for both showing 
#this property.

l= ["apple", "banana", "abc", 34, True, 40+6j, 2.50, True , False, 100, range(10)]
type(l)
# printing value in list l
print (l[2])
# replacing "abc" with "xyz"
l[2]= "xyz"
# list after replacing
print(l)
print(l[2])
# Out:
# abc
# ['apple', 'banana', 'xyz', 34, True, (40+6j), 2.5, True, False, 100, range(0, 10)]
# xyz

# %%
s="Hello"
type(s)
# printing value in string s
print (s)
# replacing "abc" with "xyz"
s[2]= "e" # Error because string is immutable
# list after replacing
print(s)
# Out:
# Hello
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 6
#       4 print (s)
#       5 # replacing "abc" with "xyz"
# ----> 6 s[2]= "e"
#       7 # list after replacing
#       8 print(s)
#
# TypeError: 'str' object does not support item assignment
